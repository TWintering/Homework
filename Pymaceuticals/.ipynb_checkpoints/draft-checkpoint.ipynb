# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
clinic=pd.read_csv('data/clinicaltrial_data.csv')
mouse=pd.read_csv('data/mouse_drug_data.csv')

# %%
mouse.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
clinic.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
df=pd.merge(clinic,mouse,on='Mouse ID')

# %%
df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin

# %%
g=df.copy()

# %%
del g['Metastatic Sites']
g.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)       Drug
# 0     b128          0           45.000000  Capomulin
# 1     b128          5           45.651331  Capomulin
# 2     b128         10           43.270852  Capomulin
# 3     b128         15           43.784893  Capomulin
# 4     b128         20           42.731552  Capomulin

# %%
gr=g.groupby(['Drug','Timepoint'])

# %%
mean_vol=gr.mean()

# %%
mean_vol
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
#           25                  39.939528
#           30                  38.769339
#           35                  37.816839
#           40                  36.958001
#           45                  36.236114
# Ceftamin  0                   45.000000
#           5                   46.503051
#           10                  48.285125
#           15                  50.094055
#           20                  52.157049
#           25                  54.287674
#           30                  56.769517
#           35                  58.827548
#           40                  61.467895
#           45                  64.132421
# Infubinol 0                   45.000000
#           5                   47.062001
# ...

# %%
mean_vol=mean_vol.reset_index() #I like it better the other way, but this matches the sample output

# %%
#group['Standard Error']=group['Tumor Volume (mm3)'].sem()

# %%
sem_vol=gr['Tumor Volume (mm3)'].sem()

# %%
sem_vol=sem_vol.reset_index()

# %%
sem_vol
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# 5   Capomulin         25            0.881642
# 6   Capomulin         30            0.934460
# 7   Capomulin         35            1.052241
# 8   Capomulin         40            1.223608
# 9   Capomulin         45            1.223977
# 10   Ceftamin          0            0.000000
# 11   Ceftamin          5            0.164505
# 12   Ceftamin         10            0.236144
# 13   Ceftamin         15            0.332053
# 14   Ceftamin         20            0.359482
# 15   Ceftamin         25            0.439356
# 16   Ceftamin         30            0.490620
# 17   Ceftamin         35            0.692248
# 18   Ceftamin         40            0.708505
# 19   Ceftamin         45            0.902358
# ...

# %%
reform=mean_vol.pivot_table('Tumor Volume (mm3)','Timepoint','Drug')

# %%
reform.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
#plt.scatter(x_axis, data, marker="o", facecolors="red", edgecolors="black", s=x_axis, alpha=0.75)

# %%
#plt.scatter(reform['Timepoint'],reform['Capomulin'],marker='O',color='red')

# %%
new=reform.reset_index()

# %%
new.head()
# Out:
# Drug  Timepoint  Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol  \
# 0             0  45.000000  45.000000  45.000000  45.000000  45.000000
# 1             5  44.266086  46.503051  47.062001  47.389175  46.796098
# 2            10  43.084291  48.285125  49.403909  49.582269  48.694210
# 3            15  42.064317  50.094055  51.296397  52.399974  50.933018
# 4            20  40.716325  52.157049  53.197691  54.920935  53.644087
#
# Drug    Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# 0     45.000000  45.000000  45.000000  45.000000  45.000000
# 1     47.125589  47.248967  43.944859  47.527452  46.851818
# 2     49.423329  49.101541  42.531957  49.463844  48.689881
# 3     51.359742  51.067318  41.495061  51.529409  50.779059
# 4     54.364417  53.346737  40.238325  54.067395  53.170334

# %%
#plt.plot(new['Timepoint'],new['Capomulin'], marker="o", color='red')
#plt.plot(new['Timepoint'],new['Infubinol'],marker='^', color='blue')
#plt.plot(new['Timepoint'],new['Ketapril'],marker='s',color='green')
#plt.plot(new['Timepoint'],new['Placebo'],marker='D', color='black')
#plt.legend(loc="upper left")
#plt.title('Tumor Response to Treatment')
#plt.xlabel("Time (Days)")
#plt.ylabel('Tumor Volume (mm3)')
#plt.grid()
#plt.tight_layout()

# %%
err=sem_vol.pivot_table('Tumor Volume (mm3)','Timepoint','Drug')

# %%
err
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
plt.plot(new['Timepoint'],new['Capomulin'], marker="o", color='red')
plt.errorbar(new['Timepoint'],new['Capomulin'],yerr=err['Capomulin'],linestyle="None",color='red',label='_nolegend_')
plt.plot(new['Timepoint'],new['Infubinol'],marker='^', color='blue')
plt.errorbar(new['Timepoint'],new['Infubinol'],yerr=err['Infubinol'],linestyle="None",color='blue',label='_nolegend_')
plt.plot(new['Timepoint'],new['Ketapril'],marker='s',color='green')
plt.errorbar(new['Timepoint'],new['Ketapril'],yerr=err['Ketapril'],linestyle="None",color='green',label='_nolegend_')
plt.plot(new['Timepoint'],new['Placebo'],marker='D', color='black')
plt.errorbar(new['Timepoint'],new['Placebo'],yerr=err['Placebo'],linestyle="None",color='black',label='_nolegend_')
plt.legend(loc="upper left")
plt.title('Tumor Response to Treatment')
plt.xlabel("Time (Days)")
plt.ylabel('Tumor Volume (mm3)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()
#plt.gcf().clear()

# %%
m=df.copy()

# %%
del m['Tumor Volume (mm3)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tumor Volume (mm3)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-342-151c532cbbfa> in <module>()
# ...

# %%
m.head()
# Out:
#   Mouse ID  Timepoint  Metastatic Sites       Drug
# 0     b128          0                 0  Capomulin
# 1     b128          5                 0  Capomulin
# 2     b128         10                 0  Capomulin
# 3     b128         15                 0  Capomulin
# 4     b128         20                 0  Capomulin

# %%
me=m.groupby(['Drug','Timepoint']).mean()

# %%
#met=me.reset_index()

# %%
#meta.head()

# %%
me_sem=m.groupby(['Drug','Timepoint']).sem()

# %%
#met_sem=meta_sem.reset_index()

# %%
#meta_sem.head()

# %%
met=me.pivot_table('Metastatic Sites','Timepoint','Drug')

# %%
met.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118

# %%
met_sem=me_sem.pivot_table('Metastatic Sites','Timepoint','Drug')

# %%
met_sem.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.095219  0.066332  0.087178   0.077709
# 10         0.105690  0.090289  0.123672   0.109109
# 15         0.136377  0.115261  0.153439   0.111677
# 20         0.171499  0.119430  0.200905   0.166378

# %%
#plt.plot(meta['Timepoint'],meta['Capomulin'], marker="o", color='red')
#plt.errorbar(meta['Timepoint'],meta['Capomulin'],yerr=meta_sem['Capomulin'],linestyle="None",color='red',label='_nolegend_')
#plt.plot(meta['Timepoint'],meta['Infubinol'],marker='^', color='blue')
#plt.errorbar(meta['Timepoint'],meta['Infubinol'],yerr=meta_sem['Infubinol'],linestyle="None",color='blue',label='_nolegend_')
#plt.plot(meta['Timepoint'],meta['Ketapril'],marker='s',color='green')
#plt.errorbar(meta['Timepoint'],meta['Ketapril'],yerr=meta_sem['Ketapril'],linestyle="None",color='green',label='_nolegend_')
#plt.plot(meta['Timepoint'],meta['Placebo'],marker='D', color='black')
#plt.errorbar(meta['Timepoint'],meta['Placebo'],yerr=meta_sem['Placebo'],linestyle="None",color='black',label='_nolegend_')
#plt.legend(loc="upper left")
#plt.title('Metastatic Spread During Treatment')
#plt.xlabel("Treatment Duration (Days)")
#plt.ylabel('Met. Sites')
#plt.grid()
#plt.tight_layout()
#plt.show()

# %%
meta=met.reset_index()

# %%
meta.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 2            10   0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 3            15   0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 4            20   0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.320000  0.120000  0.240000   0.166667
# 2     0.565217  0.250000  0.478261   0.500000
# 3     0.764706  0.333333  0.782609   0.809524
# 4     1.000000  0.347826  0.952381   1.294118

# %%
meta_sem=met_sem.reset_index()

# %%
meta_sem.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# 0             0   0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 1             5   0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 2            10   0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 3            15   0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 4            20   0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0     0.000000  0.000000  0.000000   0.000000
# 1     0.095219  0.066332  0.087178   0.077709
# 2     0.105690  0.090289  0.123672   0.109109
# 3     0.136377  0.115261  0.153439   0.111677
# 4     0.171499  0.119430  0.200905   0.166378

# %%
plt.plot(meta['Timepoint'],meta['Capomulin'], marker="o", color='red')
plt.errorbar(meta['Timepoint'],meta['Capomulin'],yerr=meta_sem['Capomulin'],linestyle="None",color='red',label='_nolegend_')
plt.plot(meta['Timepoint'],meta['Infubinol'],marker='^', color='blue')
plt.errorbar(meta['Timepoint'],meta['Infubinol'],yerr=meta_sem['Infubinol'],linestyle="None",color='blue',label='_nolegend_')
plt.plot(meta['Timepoint'],meta['Ketapril'],marker='s',color='green')
plt.errorbar(meta['Timepoint'],meta['Ketapril'],yerr=meta_sem['Ketapril'],linestyle="None",color='green',label='_nolegend_')
plt.plot(meta['Timepoint'],meta['Placebo'],marker='D', color='black')
plt.errorbar(meta['Timepoint'],meta['Placebo'],yerr=meta_sem['Placebo'],linestyle="None",color='black',label='_nolegend_')
plt.legend(loc="upper left")
plt.title('Metastatic Spread During Treatment')
plt.xlabel("Treatment Duration (Days)")
plt.ylabel('Met. Sites')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

# %%
s=df.copy()
del s['Metastatic Sites']
del s['Tumor Volume (mm3)']

# %%
s.head()
# Out:
#   Mouse ID  Timepoint       Drug
# 0     b128          0  Capomulin
# 1     b128          5  Capomulin
# 2     b128         10  Capomulin
# 3     b128         15  Capomulin
# 4     b128         20  Capomulin

# %%
s=s.groupby(['Drug','Timepoint']).count()

# %%
s=s.reset_index()

# %%
s.head()
# Out:
#         Drug  Timepoint  Mouse ID
# 0  Capomulin          0        25
# 1  Capomulin          5        25
# 2  Capomulin         10        25
# 3  Capomulin         15        24
# 4  Capomulin         20        23

# %%
s=s.rename(columns={'Mouse ID':'Mouse Count'})

# %%
mice=s.pivot_table('Mouse Count','Timepoint','Drug')

mice=mice.reset_index()

mice.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# 0             0         25        25         25        25        25       25
# 1             5         25        21         25        23        23       24
# 2            10         25        20         21        22        21       24
# 3            15         24        19         21        19        21       20
# 4            20         23        18         20        19        20       19
#
# Drug  Propriva  Ramicane  Stelasyn  Zoniferol
# 0           26        25        26         25
# 1           25        25        25         24
# 2           23        24        23         22
# 3           17        24        23         21
# 4           17        23        21         17

# %%
#I'm not hardcoding 25 in percents if some have 26
initial_mice=next(mice.iterrows())[1]

# %%
mice_percent=mice.copy()

# %%
for i in range(1,len(initial_mice)):
    mice_percent.iloc[:,i]=mice_percent.iloc[:,i]/(initial_mice[i])
    mice_percent.iloc[:,i]=mice_percent.iloc[:,i] * 100

# %%
mice_percent.head()
# Out:
# Drug  Timepoint  Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# 0             0      100.0     100.0      100.0     100.0     100.0    100.0
# 1             5      100.0      84.0      100.0      92.0      92.0     96.0
# 2            10      100.0      80.0       84.0      88.0      84.0     96.0
# 3            15       96.0      76.0       84.0      76.0      84.0     80.0
# 4            20       92.0      72.0       80.0      76.0      80.0     76.0
#
# Drug    Propriva  Ramicane    Stelasyn  Zoniferol
# 0     100.000000     100.0  100.000000      100.0
# 1      96.153846     100.0   96.153846       96.0
# 2      88.461538      96.0   88.461538       88.0
# 3      65.384615      96.0   88.461538       84.0
# 4      65.384615      92.0   80.769231       68.0

# %%
plt.plot(mice_percent['Timepoint'],mice_percent['Capomulin'], marker="o", color='red')
plt.plot(mice_percent['Timepoint'],mice_percent['Infubinol'],marker='^', color='blue')
plt.plot(mice_percent['Timepoint'],mice_percent['Ketapril'],marker='s',color='green')
plt.plot(mice_percent['Timepoint'],mice_percent['Placebo'],marker='D', color='black')
plt.legend(loc="lower left")
plt.title('Survival During Treatment')
plt.xlabel("Time (Days)")
plt.ylabel('Survival Rate (%)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

# %%
len(new.columns)
# Out:
# 11

# %%
new
# Out:
# Drug  Timepoint  Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol  \
# 0             0  45.000000  45.000000  45.000000  45.000000  45.000000
# 1             5  44.266086  46.503051  47.062001  47.389175  46.796098
# 2            10  43.084291  48.285125  49.403909  49.582269  48.694210
# 3            15  42.064317  50.094055  51.296397  52.399974  50.933018
# 4            20  40.716325  52.157049  53.197691  54.920935  53.644087
# 5            25  39.939528  54.287674  55.715252  57.678982  56.731968
# 6            30  38.769339  56.769517  58.299397  60.994507  59.559509
# 7            35  37.816839  58.827548  60.742461  63.371686  62.685087
# 8            40  36.958001  61.467895  63.162824  66.068580  65.600754
# 9            45  36.236114  64.132421  65.755562  70.662958  69.265506
#
# Drug    Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# 0     45.000000  45.000000  45.000000  45.000000  45.000000
# 1     47.125589  47.248967  43.944859  47.527452  46.851818
# ...

# %%
last=len(new['Timepoint'])-1

# %%
change=[(((new.iloc[last,x] - new.iloc[0,x]) /new.iloc[0,x]) * 100) for x in range(1,len(new.columns))]

# %%
change
# Out:
# [-19.475302667894155,
#  42.516491855897414,
#  46.12347172785184,
#  57.02879468660604,
#  53.923347134769195,
#  51.29796048315153,
#  47.24117486320634,
#  -22.32090046276666,
#  52.085134287898995,
#  46.57975086509522]

# %%
bars=dict(zip(list(new.columns),change))

# %%
bars
# Out:
# {'Timepoint': inf,
#  'Capomulin': -19.475302667894155,
#  'Ceftamin': 42.516491855897414,
#  'Infubinol': 46.12347172785184,
#  'Ketapril': 57.02879468660604,
#  'Naftisol': 53.923347134769195,
#  'Placebo': 51.29796048315153,
#  'Propriva': 47.24117486320634,
#  'Ramicane': -22.32090046276666,
#  'Stelasyn': 52.085134287898995,
#  'Zoniferol': 46.57975086509522}

# %%
plt.close()
colors={}
for key in bars:
    if bars[key]>0:
        colors[key]='red'
    else:
        colors[key]='green'

# %%
colors
# Out:
# {'Timepoint': 'red',
#  'Capomulin': 'green',
#  'Ceftamin': 'red',
#  'Infubinol': 'red',
#  'Ketapril': 'red',
#  'Naftisol': 'red',
#  'Placebo': 'red',
#  'Propriva': 'red',
#  'Ramicane': 'green',
#  'Stelasyn': 'red',
#  'Zoniferol': 'red'}

# %%
plt.close()

# %%
#plt.bar('Capomulin',bars['Capomulin'],color=colors['Capomulin'])
#plt.bar('Infubinol',bars['Infubinol'],color=colors['Infubinol'])
#plt.bar('Ketapril',bars['Ketapril'],color=colors['Ketapril'])
#plt.bar('Placebo',bars['Placebo'],color=colors['Placebo'])
#plt.title('Tumor Change Over 45 Days Treatment')
#plt.ylabel('% Tumor Volume Change')
#plt.hlines(0,-1,4)
#plt.xticks([0,1,2,3],['Capomulin','Infubinol','Ketapril','Placebo'],rotation=5)
#plt.text(-.3,-5,str(round(bars['Capomulin'],1)+'%'),color='white')
#plt.text(.7,5,round(bars['Infubinol'],2),color='white')

# %%
plt.close()

# %%
#x_axis=['Capomulin','Infubinol','Ketapril','Placebo']

# %%
#graph=np.arange(len(x_axis))

# %%
#graph
# Out:
# array([0, 1, 2, 3])

# %%
#plt.bar(x_axis,graph, color=[colors[x] for x in x_axis])
#plt.grid()

# %%
#plt.bar(x_axis,[bars[x] for x in x_axis],color=[colors[x] for x in x_axis])

# %%
plt.close()

# %%
#plt.bar(graph,[bars[x] for x in x_axis],color=[colors[x] for x in x_axis],align='center',width=0.9)
#plt.xticks(graph,x_axis, rotation=5)
#for x in x_axis:
    #plt.text(graph[x],(bars[x]/2),('d% %%' % bars[x]),color=white)
#plt.text(1,1,'FUCK',color='white')
#for x in graph:
    #plt.text(graph[x]-0.15,(bars[x_axis[x]]/2),('%d.1%%' % bars[x_axis[x]]),color='white')

# %%
plt.close()

# %%
graph=['Capomulin','Infubinol','Ketapril','Placebo']
x_axis=np.arange(len(graph))

# %%
plt.bar(x_axis,[bars[x] for x in graph],color=[colors[x] for x in graph],align='center',width=0.9)
plt.xticks(x_axis,graph,rotation=10)
for x in x_axis:
    plt.text(x_axis[x],bars[graph[x]]/2,('%d.1%%' % bars[graph[x]]),color='white',ha='center')
plt.hlines(0,x_axis.min()-0.45,x_axis.max()+0.45)
plt.ylabel('% Tumor Volume Change')
plt.title('Tumor Change Over 45 Days Treatment')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Tumor Change Over 45 Days Treatment')
